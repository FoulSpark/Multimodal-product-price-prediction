# %% [markdown]
# ##  Basic Library imports

# %%
import os
import pandas as pd 
import numpy as np

# %% [markdown]
# ##  Read Dataset

# %%
DATASET_FOLDER = '../dataset/'
train = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, 'test.csv'))
sample_test = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test.csv'))
sample_test_out = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test_out.csv'))

# %%
from utils import download_images
download_images(sample_test['image_link'], '../images')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]Exception in thread Thread-3 (_handle_workers):
# Traceback (most recent call last):
#   File "c:\Python313\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\MAYANK\AppData\Roaming\Python\Python313\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Python313\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\multiprocessing\pool.py", line 516, in _handle_workers
#     cls._maintain_pool(ctx, Process, processes, pool, inqueue,
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                        outqueue, initializer, initargs,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                        maxtasksperchild, wrap_exception)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\multiprocessing\pool.py", line 340, in _maintain_pool
#     Pool._repopulate_pool_static(ctx, Process, processes, pool,
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                                  inqueue, outqueue, initializer,
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                                  initargs, maxtasksperchild,
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                                  wrap_exception)
#                                  ^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\multiprocessing\pool.py", line 329, in _repopulate_pool_static
#     w.start()
#     ~~~~~~~^^
#   File "c:\Python313\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Python313\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Python313\Lib\multiprocessing\popen_spawn_win32.py", line 76, in __init__
#     hp, ht, pid, tid = _winapi.CreateProcess(
#                        ~~~~~~~~~~~~~~~~~~~~~^
#         python_exe, cmd,
#         ^^^^^^^^^^^^^^^^
#         None, None, False, 0, env, None,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         STARTUPINFO(dwFlags=STARTF_FORCEOFFFEEDBACK))
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [WinError 1455] The paging file is too small for this operation to complete

# %%
assert len(os.listdir('../images')) > 0

# %%
rm -rf ../images
